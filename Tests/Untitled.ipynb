# %%
a = (1, 2, 3)
a, b, c = a
a, b, c
# Out:
# (1, 2, 3)

# %%
a, (b, c) = a
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-f8a66a1621cd> in <module>
# ----> 1 a, (b, c) = a
#
# TypeError: cannot unpack non-iterable int object
